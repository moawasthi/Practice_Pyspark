# %% [markdown]
# #USE CASE :
# ### We have OrderHistory received from an OLTP system, create a star schema to do advanced order and shipment analysis

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, split, trim, col, asc

# %%
df_order_detail = spark.read.format('csv').option("header", True).option("inferSchema", True).load('/FileStore/tables/synthetic_orders_2500.csv')

# %% [markdown]
# ### Extracting Retailers

# %%
df_retailers = df_order_detail.select("Website").distinct()

# %%
retailerWindowSpec = Window.orderBy("Website")
df_retailers = df_retailers.withColumn("RetailerId", row_number().over(retailerWindowSpec))
df_retailers = df_retailers.withColumnRenamed("Website", "Retailer")

# %%
df_retailers =  df_retailers.select("RetailerId", "Retailer")

# %%
df_currency = df_order_detail.select("Currency").distinct()

# %%
currencyWindowSpec = Window.orderBy("Currency")
df_currency = df_currency.withColumn("CurrencyId", row_number().over(currencyWindowSpec))

# %%
df_currency = df_currency.select("CurrencyId", "Currency")

# %%
df_product = df_order_detail.select( "Product Condition","Product Name" ).distinct()

# %%
df_product = df_product.withColumn("Used Condition", trim(split("Product Condition", "-").getItem(1)))\
    .withColumn("Product Condition Changed", trim(split("Product Condition", "-").getItem(0)))

# %%
productWindowSpec = Window.orderBy("Product Name")
df_product = df_product.withColumn("ProductId", row_number().over(productWindowSpec) )

# %%
df_product = df_product.select("ProductId", "Product Name", "Product Condition", "Used Condition", "Product Condition Changed")

# %%
df_product = df_product.na.fill("N/A", ["Used Condition"])

# %%
df_paymentInstrumentType = df_order_detail.select("Payment Instrument Type").distinct()

# %%
windowPaymentType = Window.orderBy("Payment Instrument Type")
df_paymentInstrumentType = df_paymentInstrumentType.withColumn("PaymentTypeId", row_number().over(windowPaymentType))
df_paymentInstrumentType = df_paymentInstrumentType\
    .withColumnRenamed("Payment Instrument Type", "Payment Type")

# %%
df_paymentInstrumentType = df_paymentInstrumentType.select("PaymentTypeId", "Payment Type")

# %%
df_status = df_order_detail.select("Order Status", "Shipment Status").distinct().orderBy("Order Status", "Shipment Status")

# %%
statusWindow = Window.orderBy("Order Status", "Shipment Status")
df_status = df_status.withColumn("StatusId", row_number().over(statusWindow))\
    .select("StatusId", "Order Status", "Shipment Status")

# %%
df_customer = df_order_detail.select("Billing Address", "Shipping Address").distinct()

# %%
windowCustomer = Window.orderBy("Billing Address","Shipping Address" )
df_customer = df_customer.withColumn("CustomerId", row_number().over(windowCustomer))\
    .select("CustomerId", "Billing Address", "Shipping Address")

# %%
df_gift = df_order_detail.select("Gift Message", "Gift Recipient Contact Details", "Gift Sender Name").distinct()

# %%
giftWindow = Window.orderBy(col("Gift Message").asc(), "Gift Recipient Contact Details", "Gift Sender Name")

# %%
df_gift = df_gift.withColumn("GiftId", row_number().over(giftWindow)).select("GiftId","Gift Message", "Gift Recipient Contact Details", "Gift Sender Name")

# %%
df_gift =df_gift.na.fill("N/A")

# %%
df_od = df_order_detail.alias("od")
df_p = df_product.alias("p")
df_pay = df_paymentInstrumentType.alias("pay")
df_cust = df_customer.alias("cus")
df_status = df_status.alias("stat")
df_gift = df_gift.alias("gift")
fact_orders = (
    df_od.join(
        df_retailers, how="left", on=df_order_detail.Website == df_retailers.Retailer
    )
    .join(df_currency, how="left", on=df_order_detail.Currency == df_currency.Currency)
    .join(
        df_p,
        how="left",
        on=(col("od.`Product Name`") == col("p.`Product Name`"))
        & (col("od.`Product Condition`") == col("p.`Product Condition`"))
    )
    .join(
        df_pay,
        how="left",
        on=col("od.`Payment Instrument Type`") == col("pay.`Payment Type`")
    )
    .join(
        df_cust,
        how="left",
        on=(col("od.`Billing Address`") == col("cus.`Billing Address`"))
        & (col("od.`Shipping Address`") == col("cus.`Shipping Address`"))
    )
    .join(
        df_status,
        how="left",
        on=(col("od.`Order Status`") == col("stat.`Order Status`"))
        & (col("od.`Shipment Status`") == col("stat.`Shipment Status`"))
    )
    .join(
        df_gift,
        how="left",
        on=  (col("od.`Gift Message`") == col("gift.`Gift Message`"))
                & (col("od.`Gift Recipient Contact Details`") == col("gift.`Gift Recipient Contact Details`"))
                & (col("od.`Gift Sender Name`") == col("gift.`Gift Sender Name`"))
    )
    .select( col("od.ASIN"),
        df_retailers.RetailerId,
        df_currency.CurrencyId,
        df_product.ProductId,
        df_pay.PaymentTypeId,
        df_cust.CustomerId,
        df_status.StatusId,
        df_gift.GiftId,
        col("od.`Order ID`"),
        col("od.`Order Date`"),
        col("od.`Purchase Order Number`"),
        col("od.`Unit Price`"),
        col("od.`Unit Price Tax`"),
        col("od.`Shipping Charge`"),
        col("od.`Total Discounts`"),
        col("od.`Total Owed`"),
        col("od.`Shipment Item Subtotal Tax`"),
        col("od.`Quantity`"),
        col("od.`Ship Date`"),
        col("od.`Item Serial Number`")
    )
)

# %% [markdown]
# ### Display the records in place of writing

# %%
display(df_customer)
display(df_retailers)
display(df_currency)
display(df_product)
display(df_paymentInstrumentType)
display(df_status)
display(df_gift)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerId</th><th>Billing Address</th><th>Shipping Address</th></tr></thead><tbody><tr><td>1</td><td>1 Elm St, City 30, USA</td><td>983 Main St, City 37, USA</td></tr><tr><td>2</td><td>1 Elm St, City 69, USA</td><td>952 Main St, City 85, USA</td></tr><tr><td>3</td><td>1 Elm St, City 87, USA</td><td>376 Main St, City 38, USA</td></tr><tr><td>4</td><td>10 Elm St, City 22, USA</td><td>784 Main St, City 41, USA</td></tr><tr><td>5</td><td>10 Elm St, City 42, USA</td><td>341 Main St, City 27, USA</td></tr><tr><td>6</td><td>101 Elm St, City 25, USA</td><td>889 Main St, City 63, USA</td></tr><tr><td>7</td><td>101 Elm St, City 4, USA</td><td>547 Main St, City 59, USA</td></tr><tr><td>8</td><td>102 Elm St, City 12, USA</td><td>593 Main St, City 23, USA</td></tr><tr><td>9</td><td>102 Elm St, City 4, USA</td><td>936 Main St, City 40, USA</td></tr><tr><td>10</td><td>102 Elm St, City 72, USA</td><td>
...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>RetailerId</th><th>Retailer</th></tr></thead><tbody><tr><td>1</td><td>Amazon</td></tr><tr><td>2</td><td>Best Buy</td></tr><tr><td>3</td><td>eBay</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CurrencyId</th><th>Currency</th></tr></thead><tbody><tr><td>1</td><td>EUR</td></tr><tr><td>2</td><td>GBP</td></tr><tr><td>3</td><td>USD</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ProductId</th><th>Product Name</th><th>Product Condition</th><th>Used Condition</th><th>Product Condition Changed</th></tr></thead><tbody><tr><td>1</td><td>Product-100</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>2</td><td>Product-100</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>3</td><td>Product-100</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>4</td><td>Product-101</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>5</td><td>Product-101</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>6</td><td>Product-102</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>7</td><td>Product-104</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>8</td><td>Product-104</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>9</td><td>Product-105</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>10</td><td>Product-106</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>11</td><td>Product-106</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>12</td><td>Product-107</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>13</td><td>Product-108</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>14</td><td>Product-109</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>15</td><td>Product-110</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>16</td><td>Product-110</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>17</td><td>Product-110</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>18</td><td>Product-111</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>19</td><td>Product-111</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>20</td><td>Product-112</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>21</td><td>Product-112</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>22</td><td>Product-113</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>23</td><td>Product-113</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>24</td><td>Product-114</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>25</td><td>Product-114</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>26</td><td>Product-114</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>27</td><td>Product-115</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>28</td><td>Product-115</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>29</td><td>Product-116</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>30</td><td>Product-116</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>31</td><td>Product-116</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>32</td><td>Product-118</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>33</td><td>Product-118</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>34</td><td>Product-119</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>35</td><td>Product-119</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>36</td><td>Product-119</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>37</td><td>Product-120</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>38</td><td>Product-120</td><td>Used - Acceptable</td><td>Acceptable</td><td>Used</td></tr><tr><td>39</td><td>Product-121</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>40</td><td>Product-122</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>41</td><td>Product-122</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>42</td><td>Product-123</td><td>Used - Good</td><td>Good</td><td>Used</td></tr><tr><td>43</td><td>Product-123</td><td>New</td><td>N/A</td><td>New</td></tr><tr><td>44</td><td>Product-124</td>< ...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PaymentTypeId</th><th>Payment Type</th></tr></thead><tbody><tr><td>1</td><td>Credit Card</td></tr><tr><td>2</td><td>Debit Card</td></tr><tr><td>3</td><td>PayPal</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>StatusId</th><th>Order Status</th><th>Shipment Status</th></tr></thead><tbody><tr><td>1</td><td>Pending</td><td>Delivered</td></tr><tr><td>2</td><td>Pending</td><td>In Transit</td></tr><tr><td>3</td><td>Pending</td><td>Pending</td></tr><tr><td>4</td><td>Processing</td><td>Delivered</td></tr><tr><td>5</td><td>Processing</td><td>In Transit</td></tr><tr><td>6</td><td>Processing</td><td>Pending</td></tr><tr><td>7</td><td>Shipped</td><td>Delivered</td></tr><tr><td>8</td><td>Shipped</td><td>In Transit</td></tr><tr><td>9</td><td>Shipped</td><td>Pending</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>